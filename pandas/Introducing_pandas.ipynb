# %% [markdown]
# ## The Pandas Series Object
#
# A **Pandas Series** is a one dimensional array of indexed data. It can be created from a list or array

# %%
import numpy as np
import pandas as pd

# %%
data = pd.Series([.25, .05, .75, 1.5])
data
# Out:
# 0    0.25
# 1    0.05
# 2    0.75
# 3    1.50
# dtype: float64

# %% [markdown]
# **Series** combines a sequence of values with an explicit sequence of indices which we can access with the values and index attributes

# %%
data.values
# Out:
# array([0.25, 0.05, 0.75, 1.5 ])

# %%
data.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
data[1] # same for accessing data
# Out:
# np.float64(0.05)

# %% [markdown]
# ## Series as Generalized Numpy Array

# %% [markdown]
# Numpy array has an implicitly defined integer index used to access the values the pandas series has an explicitly defined index associated with values

# %%
data = pd.Series([0.25, 0.50, 0.75, 1.1], index=['a', 'b', 'c', 'd'])
data
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.10
# dtype: float64

# %%
data['a']
# Out:
# np.float64(0.25)

# %% [markdown]
# ## Series as Specialized Dictionary
#
# A dictionary is a structure that maps typed arbitrary keys to a set of arbitrary values, and a Series is a structure that maps typed keys to a set of typed values.
#
# The type inforamtion of a pandas series makes it more efficient than python dictionaries for certain operations

# %%
population_dict = {'California': 39538223, 'Texas': 26448193, 'New York': 19651127, 'Florida': 21538187, 'Pennsylvania': 12802503 }
population = pd.Series(population_dict)
population
# Out:
# California      39538223
# Texas           26448193
# New York        19651127
# Florida         21538187
# Pennsylvania    12802503
# dtype: int64

# %%
population['California']
# Out:
# np.int64(39538223)

# %% [markdown]
# ## The Pandas DataFrame object
#
# the **DataFrame** can be thought of either as a generalization of a Numpy array or as a specialization of a python dictionary

# %% [markdown]
# ### DataFrame as Generalized Numpy array
#
# A **Dataframe** is an analog of a two dimensional array with explicit row and column indices.
#
# **Dataframe** as a sequence of aligned series objects.

# %%
area_dict = {'California': 423967, 'Texas': 695662, 'Florida': 170312, 'New York': 141297, 'Pennsylvania': 119280}
area = pd.Series(area_dict)
area
# Out:
# California      423967
# Texas           695662
# Florida         170312
# New York        141297
# Pennsylvania    119280
# dtype: int64

# %%
states = pd.DataFrame({'population': population, 'area': area})
states
# Out:
#               population    area
# California      39538223  423967
# Florida         21538187  170312
# New York        19651127  141297
# Pennsylvania    12802503  119280
# Texas           26448193  695662

# %%
states.index
# Out:
# Index(['California', 'Florida', 'New York', 'Pennsylvania', 'Texas'], dtype='object')

# %%
states.columns
# Out:
# Index(['population', 'area'], dtype='object')

# %% [markdown]
# **Dataframe** can be thought as a generalization of a two dimensional numpy array, where both row and columns have a generalized  index for accessing the data.

# %% [markdown]
# ## Constructing Dataframe Objects

# %% [markdown]
# ## From a single Series object
#
# A **Dataframe** is a collection of series objects, and a single column dataframe can be constructed from a single series

# %%
pd.DataFrame(population, columns=['population'])
# Out:
#               population
# California      39538223
# Texas           26448193
# New York        19651127
# Florida         21538187
# Pennsylvania    12802503

# %% [markdown]
# ## From a list of dicts
#
# Any list of dictionaries can be made into a Dataframe

# %%
data = [{'a': i, 'b': 2 * i}
        for i in range(3)]
pd.DataFrame(data)
# Out:
#    a  b
# 0  0  0
# 1  1  2
# 2  2  4

# %% [markdown]
# ## From a two dimensional Numpy array

# %%
pd.DataFrame(np.random.rand(3, 2), columns=['foo', 'bar'], index=['a', 'b', 'c'])
# Out:
#         foo       bar
# a  0.434691  0.370893
# b  0.992970  0.963667
# c  0.228908  0.991693

# %% [markdown]
# ## From a Numpy structured array
#
# A pandas  dataframe operates much like a structured array, can be directly from one

# %%
A = np.zeros(3, dtype=[('A', 'i8'), ('B', 'f8')])
A
# Out:
# array([(0, 0.), (0, 0.), (0, 0.)], dtype=[('A', '<i8'), ('B', '<f8')])

# %%
pd.DataFrame(A)
# Out:
#    A    B
# 0  0  0.0
# 1  0  0.0
# 2  0  0.0

# %%
ind = pd.Index([2,3,5,7,9])
ind
# Out:
# Index([2, 3, 5, 7, 9], dtype='int64')

# %%
ind[1]
# Out:
# np.int64(3)

# %%
ind[::2]
# Out:
# Index([2, 5, 9], dtype='int64')

# %%
ind[1] = 0 # index is an immutable array
# Out:
# np.int64(3)

# %%
indA = pd.Index([1,3,5,7,9])
indB = pd.Index([2,3,5,7,11])

# %%
indA.intersection(indB)
# Out:
# Index([3, 5, 7], dtype='int64')

# %%
indA.union(indB)
# Out:
# Index([1, 2, 3, 5, 7, 9, 11], dtype='int64')

# %%
indA.symmetric_difference(indB)
# Out:
# Index([1, 2, 9, 11], dtype='int64')
